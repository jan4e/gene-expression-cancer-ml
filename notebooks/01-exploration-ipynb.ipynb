# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
    for filename in filenames:
        print("  ", filename)
# Out:
# /kaggle/input
# /kaggle/input/gene-expression-cancer-rna-seq
# /kaggle/input/gene-expression-cancer-rna-seq/TCGA-PANCAN-HiSeq-801x20531
# /kaggle/input/gene-expression-cancer-rna-seq/TCGA-PANCAN-HiSeq-801x20531/TCGA-PANCAN-HiSeq-801x20531
#    data.csv
#    labels.csv

# %%
data_path = "/kaggle/input/gene-expression-cancer-rna-seq/TCGA-PANCAN-HiSeq-801x20531/TCGA-PANCAN-HiSeq-801x20531/data.csv"
labels_path = "/kaggle/input/gene-expression-cancer-rna-seq/TCGA-PANCAN-HiSeq-801x20531/TCGA-PANCAN-HiSeq-801x20531/labels.csv"

X = pd.read_csv(data_path)
y = pd.read_csv(labels_path)

# %%
X.head()

y.head()
# Out:
#   Unnamed: 0 Class
# 0   sample_0  PRAD
# 1   sample_1  LUAD
# 2   sample_2  PRAD
# 3   sample_3  PRAD
# 4   sample_4  BRCA

# %%
print("Feature matrix shape:", X.shape)
print("Labels shape:", y.shape)
# Out:
# Feature matrix shape: (801, 20532)
# Labels shape: (801, 2)

# %%
y.columns
# Out:
# Index(['Unnamed: 0', 'Class'], dtype='object')

# %%
y = y['Class']

# %%
y.value_counts()
# Out:
# Class
# BRCA    300
# KIRC    146
# LUAD    141
# PRAD    136
# COAD     78
# Name: count, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Columns: 20532 entries, Unnamed: 0 to gene_20530
# dtypes: float64(20531), object(1)
# memory usage: 125.5+ MB

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=y)
plt.title("Distribution of Cancer Types")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Notes
#
# - The dataset contains RNA-Seq gene expression values for 801 samples.
# - Each sample has expression levels for over 20,000 genes.
# - The target variable represents different cancer types.
# - The data is high-dimensional, which makes it suitable for testing different machine learning models.
